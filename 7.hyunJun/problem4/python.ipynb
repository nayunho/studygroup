# %%
# 문제. 500명의 키와 몸무게, 비만도 라벨을 이용해 비만을 판단하는 모델을 만들어보자
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# 1. bmi데이터 가져오기(카톡방의 csv파일)
df = pd.read_csv("./data/bmi_500.csv")
print(df)
# 2. 데이터 시각화하기(산점도로 출력)

t=df.loc[df.Label=="Obesity",:]
plt.scatter(t["Weight"],t["Height"] ,color="pink", label="Obesity")

t=df.loc[df.Label=="Overweight",:]
plt.scatter(t["Weight"],t["Height"] ,color="red", label="Overweight")

t=df.loc[df.Label=="Extremely Weak",:]
plt.scatter(t["Weight"],t["Height"] ,color="yellow", label="Extremely Weak")

t=df.loc[df.Label=="Normal",:]
plt.scatter(t["Weight"],t["Height"] ,color="green", label="Normal")

t=df.loc[df.Label=="Extreme Obesity",:]
plt.scatter(t["Weight"],t["Height"] ,color="black", label="Extreme Obesity")

t=df.loc[df.Label=="Weak",:]
plt.scatter(t["Weight"],t["Height"] ,color="blue", label="Weak")
plt.legend()
plt.show()
# Out:
#      Gender  Height  Weight            Label
# 0      Male     174      96          Obesity
# 1      Male     189      87           Normal
# 2    Female     185     110          Obesity
# 3    Female     195     104       Overweight
# 4      Male     149      61       Overweight
# ..      ...     ...     ...              ...
# 495  Female     150     153  Extreme Obesity
# 496  Female     184     121          Obesity
# 497  Female     141     136  Extreme Obesity
# 498    Male     150      95  Extreme Obesity
# 499    Male     173     131  Extreme Obesity
#
# [500 rows x 4 columns]

# %%
# 3. 모델링 학습 및 평가 후 예측하기(이웃의 수는 10으로 설정)
from sklearn.model_selection import train_test_split
df = pd.read_csv('./data/bmi_500.csv')

X=df.loc[:,["Height","Height"]]
y=df.loc[:,["Label"]]


X_train = X.loc[0:400,:]
X_test = X.loc[400:499,:]
y_train = y.loc[0:400,:]
y_test = y.loc[400:499,:]

knn=KNeighborsClassifier(n_neighbors=10).fit(X_train,y_train)
y_pred = knn.predict(X_test)
res = metrics.accuracy_score(y_test, y_pred)
res

# 4. 원하는 값 입력해보기(키, 몸무게)
model.predict([[168,63]])
#2차원배열 => 모델이 여러 개의 샘플을 동시에 처리할 수 있도록 하기 위한 것
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Normal'], dtype=object)
